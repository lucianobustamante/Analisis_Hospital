# %%
#Importamos todos los paquetes que voy a necitar 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from math import sqrt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e1bd1e83-8f4f-4d92-a445-814f662be80f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e1bd1e83-8f4f-4d92-a445-814f662be80f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving RecienNacidos.csv to RecienNacidos.csv
# ...

# %%
#cargamos nuestro dataset
wine = pd.read_csv('RecienNacidos.csv')

# %%
# miramos el dataset 
wine.head()
# Out:
#    ID_MUJER FACILIDAD REGION_RES_MADRE  ... GENERO SEMANA_GESTACION PESO_BEBE
# 0     10191  Hospital             Otro  ...      M             37.0      6.81
# 1     28767  Hospital             Otro  ...      M             40.0      7.37
# 2     24796  Hospital          Bayamon  ...      F             41.0      7.19
# 3       113  Hospital         Carolina  ...      M             38.0      6.50
# 4     18564  Hospital         Carolina  ...      F             39.0      7.31
#
# [5 rows x 21 columns]

# %%
# miramos ahora las tipologia de variables que tenemos
#float son valores numericos 
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID_MUJER              1000 non-null   int64
#  1   FACILIDAD             1000 non-null   object
#  2   REGION_RES_MADRE      1000 non-null   object
#  3   ORIGEN                1000 non-null   object
#  4   CASADA                1000 non-null   object
#  5   EDUC_MADRE            1000 non-null   object
#  6   EDAD_MADRE            1000 non-null   int64
#  7   RAZA_MADRE            1000 non-null   object
#  8   EDAD_PADRE            1000 non-null   object
#  9   RAZA_PADRE            1000 non-null   object
#  10  MES_CUIDADO_PRENATAL  1000 non-null   object
#  11  FUMADORA              1000 non-null   object
#  12  PESO_ANTES_EMB        996 non-null    float64
#  13  PESO_DESPUES_EMB      994 non-null    float64
#  14  PESO_GANADO           991 non-null    float64
# ...

# %%
wine.describe()
#lo que hago es ver la descripcion 
#mean, promedio
# Out:
#            ID_MUJER   EDAD_MADRE  ...  SEMANA_GESTACION   PESO_BEBE
# count   1000.000000  1000.000000  ...        996.000000  994.000000
# mean   20512.320000    25.697000  ...         37.795181    6.760433
# std    11905.631169     6.042657  ...          2.471184    1.171485
# min       59.000000    14.000000  ...         17.000000    1.000000
# 25%    10270.500000    21.000000  ...         37.000000    6.060000
# 50%    20233.000000    25.000000  ...         38.000000    6.780000
# 75%    30552.000000    30.000000  ...         39.000000    7.500000
# max    41029.000000    45.000000  ...         46.000000   10.630000
#
# [8 rows x 9 columns]

# %%
# hago un boxplot de la variable peso_bebe, se puede encontrar ciertas anomalias fuera del rango, siendo gasto atipicos y poco comunes
#si analizamos el peso de cada bebe, ronda en un parametro normal cerca de los 7 kilos
sns.boxplot(y = 'PESO_BEBE', data = wine)

# %%
sns.boxplot(y = 'EDAD_MADRE', data = wine)
#LA EDAD PROMEDIO DE LAS MADRES RONDA EN LOS 25 AÑOS

# %%
sns.countplot(x='REGION_RES_MADRE', data=wine)

# %%
sns.countplot(x='ORIGEN', data=wine)

# %%
#seguimos con un histograma
sns.distplot(wine['PESO_BEBE'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# ahora vamos a ver si hay valores faltantes
wine.isnull().sum()
# Out:
# ID_MUJER                0
# FACILIDAD               0
# REGION_RES_MADRE        0
# ORIGEN                  0
# CASADA                  0
# EDUC_MADRE              0
# EDAD_MADRE              0
# RAZA_MADRE              0
# EDAD_PADRE              0
# RAZA_PADRE              0
# MES_CUIDADO_PRENATAL    0
# FUMADORA                0
# PESO_ANTES_EMB          4
# PESO_DESPUES_EMB        6
# PESO_GANADO             9
# metodo_parto            0
# METODO_PARTO            0
# PLURALIDAD              0
# GENERO                  0
# SEMANA_GESTACION        4
# PESO_BEBE               6
# dtype: int64

# %%
# ya que son pocos, podemos quitar estas lineas
wine = wine[wine['PESO_BEBE'].notna()]
wine = wine[wine['SEMANA_GESTACION'].notna()]
wine = wine[wine['PESO_GANADO'].notna()]
wine = wine[wine['PESO_DESPUES_EMB'].notna()]
wine = wine[wine['PESO_ANTES_EMB'].notna()]

# %%
# comprobamos ahora que se hayan eliminado
print(wine['PESO_BEBE'].isnull().sum())
print(wine['SEMANA_GESTACION'].isnull().sum())
print(wine['PESO_GANADO'].isnull().sum())
print(wine['PESO_DESPUES_EMB'].isnull().sum())
print(wine['PESO_ANTES_EMB'].isnull().sum())
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
sns.boxplot(y = 'PESO_GANADO', data = wine)
#LA MAYORIA DE LAS MUJERES GANO CASI 30 KILOS, PARA SER EXACTO 26,56 EN PROMEDIO

# %%
# Primero empezamos con el scatter plot
sns.relplot(x="PESO_BEBE", y="EDAD_MADRE", data=wine)
#podemos observar, que por ejemplo una madre de 45 años vario significativamente el peso del bebe pasando los 7 kilos
# otro caso que podemos apreciar, es que en los adolecentes el peso tiende a ser mas bajo

# %%
# y si queremos mirar todos los scatter plot?
sns.pairplot(wine)

# %%
sns.countplot(x='CASADA', data=wine)
